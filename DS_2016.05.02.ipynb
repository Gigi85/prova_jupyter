# %%
# The usual preamble
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt

# Make the graphs a bit prettier, and bigger
pd.set_option('display.mpl_style', 'default')

# This is necessary to show lots of columns in pandas 0.12. 
# Not necessary in pandas 0.13.
pd.set_option('display.width', 5000) 
pd.set_option('display.max_columns', 60)

plt.rcParams['figure.figsize'] = (15, 5)

# %%
python_input_file1="C:/Users/ciapponil/Desktop/input_jupyter/lpt.csv"
test_lpt=pd.read_csv(python_input_file1, sep=';', nrows=10)

# %%
test_lpt[:5]
# Out:
#                      ds_elite.log_pagetagging.rowkey ds_elite.log_pagetagging.abtesth ds_elite.log_pagetagging.action ds_elite.log_pagetagging.actioncontext ds_elite.log_pagetagging.cacheversion ds_elite.log_pagetagging.code10  ds_elite.log_pagetagging.code8 ds_elite.log_pagetagging.device ds_elite.log_pagetagging.deviceso ds_elite.log_pagetagging.dt_loglocal ds_elite.log_pagetagging.dt_utc            ds_elite.log_pagetagging.filename ds_elite.log_pagetagging.httpmethod ds_elite.log_pagetagging.ip ds_elite.log_pagetagging.landingpage ds_elite.log_pagetagging.latitude ds_elite.log_pagetagging.longitude ds_elite.log_pagetagging.nationurl ds_elite.log_pagetagging.originaldevice ds_elite.log_pagetagging.page ds_elite.log_pagetagging.querystring                   ds_elite.log_pagetagging.rawline                  ds_elite.log_pagetagging.referrer ds_elite.log_pagetagging.regionname ds_elite.log_pagetagging.sitecountry ds_elite.log_pagetagging.sitedivision ds_elite.log_pagetagging.store ds_
# ...

# %%
python_input_file2="C:/Users/ciapponil/Desktop/input_jupyter/LPT_TPvalue_REFERRER_query_result.csv"
LPT_TPvalue_REFERRER=pd.read_csv(python_input_file2, sep=',')

# %%
LPT_TPvalue_REFERRER
# Out:
#      ds_elite.a_lpt_tpvalue_referrer.sitedivision ds_elite.a_lpt_tpvalue_referrer.store ds_elite.a_lpt_tpvalue_referrer.tpvalue_referrer  ds_elite.a_lpt_tpvalue_referrer._c3
# 0                                             NaN                                   amq                                              NaN                               114588
# 1                                             NaN                                   amq                                           101592                                   14
# 2                                             NaN                                   amq                                           111279                                    1
# 3                                             NaN                                   amq                                           115423                                  146
# ...
